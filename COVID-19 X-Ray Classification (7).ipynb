# %%
# Dataset from: https://www.kaggle.com/tawsifurrahman/covid19-radiography-database?

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from random import shuffle
import random
import os

# %% [markdown]
# # Define Constants

# %%
path = 'C:\\Users\\faiza\\COVID-19 Deep Learning\\'

IMAGE_WIDTH = 200
IMAGE_HEIGHT = 200

IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# %% [markdown]
# # Prepare Training Data

# %%
directories = ['train']
imageData = []
categories = []
    
files = os.listdir(path + directories[0])

for img in files:

    fileName = img.split('.')[0]
    
    if 'NORMAL' in fileName:
        imageData.append([fileName, 0])
        categories.append(0)

    elif 'COVID-19' in fileName:
        imageData.append([fileName, 1])
        categories.append(1)

    else:
        imageData.append([fileName, 2])
        categories.append(2)


fileNames = os.listdir(path + directories[0])

df = pd.DataFrame({
    'filename': fileNames,
    'category': categories
})

# %%
df.head()
# Out:
#              filename  category
# 0    COVID-19 (1).png         1
# 1   COVID-19 (10).png         1
# 2  COVID-19 (100).png         1
# 3  COVID-19 (101).png         1
# 4  COVID-19 (102).png         1

# %%
df.tail()
# Out:
#                      filename  category
# 695  Viral Pneumonia (95).png         2
# 696  Viral Pneumonia (96).png         2
# 697  Viral Pneumonia (97).png         2
# 698  Viral Pneumonia (98).png         2
# 699  Viral Pneumonia (99).png         2

# %% [markdown]
# # Compare Frequencies

# %%
'''
0 Represents Normal 
1 Represents COVID-19
2 Represents Viral Pneumonia 
'''
df['category'].value_counts().plot.bar()

# %% [markdown]
# # Load Random Image

# %%
sample = random.choice(os.listdir(path + directories[0]))
image = load_img(path + '\\train\\' + sample)

print(sample)
plt.imshow(image)
# Out:
# Viral Pneumonia (129).png

# %% [markdown]
# # Build Model
#
# 1. **Input Layer**: This represents our input image data. It will reshape the image into a single dimensional array. For example, if your image is 64x64, it will convert to (4096,1) array (64x64 = 4096).
#
#
# 2. **Conv Layer**: This layer will extract features from image.
#
#
# 3. **Pooling Layer**: This layer will reduce the spatial volume of input image after convolution.
#
#
# 4. **Fully Connected Layer**: This will connect the network from a layer to another layer
#
#
# 5. **Output Layer**: This is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax')) 

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From c:\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 198, 198, 32)      896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 198, 198, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 99, 99, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 97, 97, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 46, 46, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               34669056
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 34,766,787
# Trainable params: 34,765,315
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# # Callbacks
#
# ## Early Stop
#
# To prevent overfitting, we will stop the learning after 10 epochs and if the val_loss value has not decreased

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# # Learning Rate Reduction
#
# We will reduce the learning rate when then accuracy does not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', 
                                            patience = 2, 
                                            verbose = 1, 
                                            factor = 0.5, 
                                            min_lr = 0.00001)

callbacks = [earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'Normal', 1: 'COVID-19', 2: 'Viral Pneumonia'})

# %% [markdown]
# # Shuffle Data

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                       filename         category
# 0    Viral Pneumonia (194).png  Viral Pneumonia
# 1             NORMAL (207).png           Normal
# 2     Viral Pneumonia (70).png  Viral Pneumonia
# 3            COVID-19 (90).png         COVID-19
# 4            COVID-19 (80).png         COVID-19
# 5    Viral Pneumonia (172).png  Viral Pneumonia
# 6    Viral Pneumonia (171).png  Viral Pneumonia
# 7    Viral Pneumonia (247).png  Viral Pneumonia
# 8           COVID-19 (192).jpg         COVID-19
# 9    Viral Pneumonia (169).png  Viral Pneumonia
# 10            NORMAL (124).png           Normal
# 11   Viral Pneumonia (129).png  Viral Pneumonia
# 12            NORMAL (216).png           Normal
# 13   Viral Pneumonia (220).png  Viral Pneumonia
# 14    Viral Pneumonia (99).png  Viral Pneumonia
# 15           COVID-19 (16).png         COVID-19
# 16          COVID-19 (179).jpg         COVID-19
# 17     Viral Pneumonia (2).png  Viral Pneumonia
# 18           COVID-19 (28).png         COVID-19
# 19    Viral Pneumonia (69).png  Viral Pneumonia
# 20           COVID-19 (57).png         COVID-19
# 21    Viral Pneumonia (43).png  Viral Pneumonia
# 22           COVID-19 (56).png         COVID-19
# 23   Viral Pneumonia (174).png  Viral Pneumonia
# 24           COVID-19 (79).png         COVID-19
# 25   Viral Pneumonia (245).png  Viral Pneumonia
# 26    Viral Pneumonia (51).png  Viral Pneumonia
# 27   Viral Pneumonia (210).png  Viral Pneumonia
# 28           COVID-19 (68).png         COVID-19
# 29    Viral Pneumonia (50).png  Viral Pneumonia
# ..                         ...              ...
# 670         COVID-19 (135).jpg         COVID-19
# 671  Viral Pneumonia (131).png  Viral Pneumonia
# 672           NORMAL (231).png           Normal
# 673            NORMAL (48).png           Normal
# 674           NORMAL (135).png           Normal
# 675           NORMAL (245).png           Normal
# 676          COVID-19 (65).png         COVID-19
# 677    Viral Pneumonia (4).png  Viral Pneumonia
# 678            NORMAL (32).png           Normal
# 679          COVID-19 (32).png         COVID-19
# 680  Viral Pneumonia (157).png  Viral Pneumonia
# 681           NORMAL (190).png           Normal
# 682  Viral Pneumonia (193).png  Viral Pneumonia
# 683         COVID-19 (144).jpg         COVID-19
# 684         COVID-19 (153).jpg         COVID-19
# 685         COVID-19 (187).jpg         COVID-19
# 686   Viral Pneumonia (16).png  Viral Pneumonia
# 687           NORMAL (130).png           Normal
# 688           NORMAL (162).png           Normal
# 689            NORMAL (91).png           Normal
# 690           NORMAL (202).png           Normal
# 691         COVID-19 (131).png         COVID-19
# 692           NORMAL (123).png           Normal
# 693   Viral Pneumonia (60).png  Viral Pneumonia
# 694   Viral Pneumonia (53).png  Viral Pneumonia
# 695  Viral Pneumonia (216).png  Viral Pneumonia
# 696            NORMAL (39).png           Normal
# 697  Viral Pneumonia (134).png  Viral Pneumonia
# 698           NORMAL (157).png           Normal
# 699   Viral Pneumonia (73).png  Viral Pneumonia
#
# [700 rows x 2 columns]

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 5

# %% [markdown]
# # Training Generator

# %%
train_datagen = ImageDataGenerator (
    
    rotation_range = 15,
    rescale = 1./255,
    
    shear_range = 0.1,
    zoom_range = 0.2,
    
    horizontal_flip = True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe (
    
    train_df, 
    path + '\\train', 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 560 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe (
    
    validate_df, 
    path + '\\train', 
    x_col ='filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 140 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Visualize Generator

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)

example_generator = train_datagen.flow_from_dataframe (
    
    example_df, 
    path + '\\train', 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
print(example_df)

plt.figure(figsize=(12, 12))

for i in range(0, 15):
    
    plt.subplot(5, 3, i+1)
    
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
        
plt.tight_layout()
plt.show()
# Out:
#             filename  category
# 0  COVID-19 (36).png  COVID-19

# %%
epochs = 25

history = model.fit_generator (
    
    train_generator, 
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,
    steps_per_epoch = total_train//batch_size,
    callbacks = callbacks
)
# Out:
# WARNING:tensorflow:From c:\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/25
# 112/112 [==============================] - 111s 994ms/step - loss: 1.5564 - accuracy: 0.5518 - val_loss: 5.5601 - val_accuracy: 0.4143
# Epoch 2/25
# 112/112 [==============================] - 110s 979ms/step - loss: 1.1175 - accuracy: 0.6607 - val_loss: 1.8880 - val_accuracy: 0.4786
# Epoch 3/25
# 112/112 [==============================] - 110s 978ms/step - loss: 0.9074 - accuracy: 0.6696 - val_loss: 3.8756 - val_accuracy: 0.5214
# Epoch 4/25
# 112/112 [==============================] - 111s 987ms/step - loss: 0.7776 - accuracy: 0.7125 - val_loss: 1.1267 - val_accuracy: 0.5429
# Epoch 5/25
# 112/112 [==============================] - 109s 975ms/step - loss: 0.6989 - accuracy: 0.7232 - val_loss: 0.5183 - val_accuracy: 0.6500
# Epoch 6/25
# 112/112 [==============================] - 110s 979ms/step - loss: 0.7413 - accuracy: 0.7500 - val_loss: 4.0875 - val_accuracy: 0.6357
# Epoch 7/25
# 112/112 [==============================] - 109s 973ms/step - loss: 0.6599 - accuracy: 0.7768 - val_loss: 8.8051 - val_accuracy: 0.2214
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/25
# 112/112 [==============================] - 110s 981ms/step - loss: 0.6044 - accuracy: 0.7911 - val_loss: 4.5125 - val_accuracy: 0.2357
# Epoch 9/25
# 112/112 [==============================] - 109s 978ms/step - loss: 0.5170 - accuracy: 0.8161 - val_loss: 1.2045 - val_accuracy: 0.4643
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/25
# 112/112 [==============================] - 110s 979ms/step - loss: 0.4586 - accuracy: 0.8357 - val_loss: 0.3835 - val_accuracy: 0.8071
# Epoch 11/25
# 112/112 [==============================] - 109s 977ms/step - loss: 0.4898 - accuracy: 0.8196 - val_loss: 0.1707 - val_accuracy: 0.9143
# Epoch 12/25
# 112/112 [==============================] - 109s 974ms/step - loss: 0.4790 - accuracy: 0.8107 - val_loss: 0.1269 - val_accuracy: 0.6143
# Epoch 13/25
# 112/112 [==============================] - 110s 981ms/step - loss: 0.4356 - accuracy: 0.8411 - val_loss: 0.7747 - val_accuracy: 0.8214
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/25
# 112/112 [==============================] - 110s 983ms/step - loss: 0.3795 - accuracy: 0.8661 - val_loss: 2.2335 - val_accuracy: 0.9214
# Epoch 15/25
# 112/112 [==============================] - 111s 989ms/step - loss: 0.3737 - accuracy: 0.8696 - val_loss: 1.3503 - val_accuracy: 0.7786
# Epoch 16/25
# 112/112 [==============================] - 109s 974ms/step - loss: 0.5004 - accuracy: 0.8179 - val_loss: 0.6174 - val_accuracy: 0.8929
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/25
# 112/112 [==============================] - 110s 983ms/step - loss: 0.4049 - accuracy: 0.8411 - val_loss: 0.0155 - val_accuracy: 0.9286
# Epoch 18/25
# 112/112 [==============================] - 109s 976ms/step - loss: 0.3705 - accuracy: 0.8518 - val_loss: 1.7777 - val_accuracy: 0.8143
# Epoch 19/25
# 112/112 [==============================] - 112s 997ms/step - loss: 0.4183 - accuracy: 0.8554 - val_loss: 0.0596 - val_accuracy: 0.9286
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/25
# 112/112 [==============================] - 109s 976ms/step - loss: 0.4262 - accuracy: 0.8607 - val_loss: 0.0926 - val_accuracy: 0.9214
# Epoch 21/25
# 112/112 [==============================] - 110s 986ms/step - loss: 0.3531 - accuracy: 0.8804 - val_loss: 0.0445 - val_accuracy: 0.9286
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 22/25
# 112/112 [==============================] - 110s 981ms/step - loss: 0.3815 - accuracy: 0.8625 - val_loss: 0.1119 - val_accuracy: 0.9214
# Epoch 23/25
# 112/112 [==============================] - 110s 979ms/step - loss: 0.3440 - accuracy: 0.8768 - val_loss: 0.0292 - val_accuracy: 0.9286
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 24/25
# 112/112 [==============================] - 110s 981ms/step - loss: 0.3471 - accuracy: 0.8732 - val_loss: 0.0868 - val_accuracy: 0.9214
# Epoch 25/25
# 112/112 [==============================] - 110s 980ms/step - loss: 0.3721 - accuracy: 0.8857 - val_loss: 0.2237 - val_accuracy: 0.9214

# %%
model.save_weights("COVID-Model-{}-{}-{}-{}.h5".format(IMAGE_WIDTH, 3, batch_size, epochs))

# %% [markdown]
# # Visualize Training Performance

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
numEpochs = range(1,  epochs + 1)
plt.plot(numEpochs, accuracy, 'g', label='Training Accuracy')
plt.plot(numEpochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
numEpochs = range(1,  epochs + 1)
plt.plot(numEpochs, loss, 'g', label='Training Loss')
plt.plot(numEpochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir(path + 'test')

test_df = pd.DataFrame({
    'filename': test_filenames
})

nb_samples = test_df.shape[0]

# %%
test_df = test_df.sample(frac=1).reset_index(drop=True)
test_df
# Out:
#                       filename
# 0             NORMAL (412).png
# 1    Viral Pneumonia (537).png
# 2             NORMAL (479).png
# 3    Viral Pneumonia (468).png
# 4             NORMAL (430).png
# 5             NORMAL (604).png
# 6           COVID-19 (228).jpg
# 7    Viral Pneumonia (528).png
# 8    Viral Pneumonia (477).png
# 9    Viral Pneumonia (596).png
# 10   Viral Pneumonia (466).png
# 11   Viral Pneumonia (540).png
# 12            NORMAL (405).png
# 13            NORMAL (401).png
# 14            NORMAL (564).png
# 15   Viral Pneumonia (352).png
# 16            NORMAL (467).png
# 17   Viral Pneumonia (618).png
# 18          COVID-19 (286).jpg
# 19          COVID-19 (217).jpg
# 20            NORMAL (459).png
# 21   Viral Pneumonia (604).png
# 22          COVID-19 (232).jpg
# 23            NORMAL (424).png
# 24   Viral Pneumonia (416).png
# 25            NORMAL (532).png
# 26          COVID-19 (218).jpg
# 27            NORMAL (508).png
# 28   Viral Pneumonia (371).png
# 29            NORMAL (368).png
# ..                         ...
# 659           NORMAL (641).png
# 660  Viral Pneumonia (623).png
# 661           NORMAL (559).png
# 662  Viral Pneumonia (530).png
# 663  Viral Pneumonia (389).png
# 664  Viral Pneumonia (390).png
# 665  Viral Pneumonia (428).png
# 666  Viral Pneumonia (600).png
# 667           NORMAL (599).png
# 668         COVID-19 (223).jpg
# 669  Viral Pneumonia (393).png
# 670  Viral Pneumonia (646).png
# 671           NORMAL (361).png
# 672           NORMAL (636).png
# 673           NORMAL (451).png
# 674  Viral Pneumonia (453).png
# 675  Viral Pneumonia (513).png
# 676           NORMAL (528).png
# 677           NORMAL (400).png
# 678         COVID-19 (287).jpg
# 679           NORMAL (471).png
# 680           NORMAL (481).png
# 681  Viral Pneumonia (553).png
# 682           NORMAL (533).png
# 683           NORMAL (582).png
# 684           NORMAL (650).png
# 685  Viral Pneumonia (396).png
# 686  Viral Pneumonia (414).png
# 687  Viral Pneumonia (362).png
# 688           NORMAL (425).png
#
# [689 rows x 1 columns]

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale = 1./255)
test_generator = test_gen.flow_from_dataframe(
    
    test_df, 
    path + '\\test', 
    x_col = 'filename',
    y_col = None,
    class_mode = None,
    target_size = IMAGE_SIZE,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 689 validated image filenames.

# %% [markdown]
# # Form Predictions

# %%
predict = model.predict_generator(test_generator, steps = np.ceil(nb_samples/batch_size))

# %% [markdown]
# ## Pick the category that has the highest probability

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({'Normal': 0, 'COVID-19': 1, 'Viral Pneumonia': 2})

# %%
test_df['category'].value_counts().plot.bar()

# %% [markdown]
# # Predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()

plt.figure(figsize=(12, 24))

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    category = row['category']
    
    img = load_img(path + 'test\\' + filename, target_size=IMAGE_SIZE)
    
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + ' Pred: (' + "{}".format(category) + ')' )
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Calculate Model Accuracy

# %%
sample_test = test_df
correctPredictions = 0

correctNormalPred = 0
correctCovidPred = 0
correctPneuPred = 0

totalNormalPred = 0
totalCovidPred = 0
totalPneuPred = 0

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    prediction = row['category']
    
    img = load_img(path + 'test\\' + filename, target_size=IMAGE_SIZE)
    
    if 'NORMAL' in filename:
        
        if prediction == 0:
            correctPredictions += 1
            correctNormalPred += 1
            
        totalNormalPred += 1
    
    if 'COVID-19' in filename:
        
        if prediction == 1: 
            correctPredictions += 1
            correctCovidPred += 1
            
        totalCovidPred += 1
    
    if 'Viral Pneumonia' in filename:
        
        if prediction == 2: 
            correctPredictions += 1
            correctPneuPred += 1
            
        totalPneuPred += 1

# %%
print('Model Accuracy:', "{:.2%}".format(correctPredictions / test_df.shape[0]))
print('Correct Predictions:', correctPredictions, 'Total Predictions:', test_df.shape[0])

print('\nNormal Predictions:', correctNormalPred, 'Accuracy', "{:.2%}".format(correctNormalPred /  totalNormalPred))
print('COVID-19 Predictions:', correctCovidPred, 'Accuracy', "{:.2%}".format(correctCovidPred /  totalCovidPred))
print('Viral Pneumonia Predictions:', correctPneuPred, 'Accuracy', "{:.2%}".format(correctPneuPred / totalPneuPred))
# Out:
# Model Accuracy: 92.74%
# Correct Predictions: 639 Total Predictions: 689
#
# Normal Predictions: 286 Accuracy 95.33%
# COVID-19 Predictions: 80 Accuracy 89.89%
# Viral Pneumonia Predictions: 273 Accuracy 91.00%

# %%
actual = []
pred = []

for row in test_df.iterrows():
    
    filename = row[1][0]
    
    if 'NORMAL' in filename: actual.append(0)
    if 'COVID-19' in filename: actual.append(1)
    if 'Viral Pneumonia' in filename: actual.append(2)
        
    pred.append(row[1][1])

# %%
print(classification_report(actual, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94       300
#            1       0.94      0.90      0.92        89
#            2       0.93      0.91      0.92       300
#
#    micro avg       0.93      0.93      0.93       689
#    macro avg       0.93      0.92      0.93       689
# weighted avg       0.93      0.93      0.93       689

# %%
confusion_matrix(actual, pred)
# Out:
# array([[286,   2,  12],
#        [  0,  80,   9],
#        [ 24,   3, 273]], dtype=int64)
