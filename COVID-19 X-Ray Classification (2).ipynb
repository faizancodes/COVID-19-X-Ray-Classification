# %%
# Dataset from: https://www.kaggle.com/tawsifurrahman/covid19-radiography-database?

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from random import shuffle
import random
import os

# %% [markdown]
# # Define Constants

# %%
path = 'C:\\Users\\faiza\\COVID-19 Deep Learning\\'

IMAGE_WIDTH = 200
IMAGE_HEIGHT = 200

IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# %% [markdown]
# # Prepare Training Data

# %%
directories = ['train']
imageData = []
categories = []
    
files = os.listdir(path + directories[0])

for img in files:

    fileName = img.split('.')[0]
    
    if 'NORMAL' in fileName:
        imageData.append([fileName, 0])
        categories.append(0)

    elif 'COVID-19' in fileName:
        imageData.append([fileName, 1])
        categories.append(1)

    else:
        imageData.append([fileName, 2])
        categories.append(2)


fileNames = os.listdir(path + directories[0])

df = pd.DataFrame({
    'filename': fileNames,
    'category': categories
})

# %%
df.head()
# Out:
#              filename  category
# 0    COVID-19 (1).png         1
# 1   COVID-19 (10).png         1
# 2  COVID-19 (100).png         1
# 3  COVID-19 (101).png         1
# 4  COVID-19 (102).png         1

# %%
df.tail()
# Out:
#                      filename  category
# 695  Viral Pneumonia (95).png         2
# 696  Viral Pneumonia (96).png         2
# 697  Viral Pneumonia (97).png         2
# 698  Viral Pneumonia (98).png         2
# 699  Viral Pneumonia (99).png         2

# %% [markdown]
# # Compare Frequencies

# %%
'''
0 Represents Normal 
1 Represents COVID-19
2 Represents Viral Pneumonia 
'''
df['category'].value_counts().plot.bar()

# %% [markdown]
# # Load Random Image

# %%
sample = random.choice(os.listdir(path + directories[0]))
image = load_img(path + '\\train\\' + sample)

print(sample)
plt.imshow(image)
# Out:
# Viral Pneumonia (184).png

# %% [markdown]
# # Build Model
#
# 1. **Input Layer**: This represents our input image data. It will reshape the image into a single dimensional array. For example, if your image is 64x64, it will convert to (4096,1) array (64x64 = 4096).
#
#
# 2. **Conv Layer**: This layer will extract features from image.
#
#
# 3. **Pooling Layer**: This layer will reduce the spatial volume of input image after convolution.
#
#
# 4. **Fully Connected Layer**: This will connect the network from a layer to another layer
#
#
# 5. **Output Layer**: This is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax')) 

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From c:\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 198, 198, 32)      896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 198, 198, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 99, 99, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 97, 97, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 46, 46, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               34669056
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 34,766,787
# Trainable params: 34,765,315
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# # Callbacks
#
# ## Early Stop
#
# To prevent overfitting, we will stop the learning after 10 epochs and if the val_loss value has not decreased

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# # Learning Rate Reduction
#
# We will reduce the learning rate when then accuracy does not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', 
                                            patience = 2, 
                                            verbose = 1, 
                                            factor = 0.5, 
                                            min_lr = 0.00001)

callbacks = [earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'Normal', 1: 'COVID-19', 2: 'Viral Pneumonia'})

# %% [markdown]
# # Shuffle Data

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#
 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 560 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe (
    
    validate_df, 
    path + '\\train', 
    x_col ='filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 140 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Visualize Generator

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)

example_generator = train_datagen.flow_from_dataframe (
    
    example_df, 
    path + '\\train', 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
print(example_df)

plt.figure(figsize=(12, 12))

for i in range(0, 15):
    
    plt.subplot(5, 3, i+1)
    
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
        
plt.tight_layout()
plt.show()
# Out:
#                    filename         category
# 0  Viral Pneumonia (91).png  Viral Pneumonia

# %%
epochs = 15

history = model.fit_generator (
    
    train_generator, 
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,
    steps_per_epoch = total_train//batch_size,
    callbacks = callbacks
)
# Out:
# WARNING:tensorflow:From c:\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/15
# 56/56 [==============================] - 97s 2s/step - loss: 1.2240 - accuracy: 0.6536 - val_loss: 6.2048 - val_accuracy: 0.3571
# Epoch 2/15
# 56/56 [==============================] - 94s 2s/step - loss: 0.7786 - accuracy: 0.7446 - val_loss: 5.5181 - val_accuracy: 0.3643
# Epoch 3/15
# 56/56 [==============================] - 99s 2s/step - loss: 0.8112 - accuracy: 0.7500 - val_loss: 6.6432 - val_accuracy: 0.3714
# Epoch 4/15
# 56/56 [==============================] - 96s 2s/step - loss: 0.6947 - accuracy: 0.7911 - val_loss: 5.8294 - val_accuracy: 0.3571
# Epoch 5/15
# 56/56 [==============================] - 96s 2s/step - loss: 0.6198 - accuracy: 0.7982 - val_loss: 3.7658 - val_accuracy: 0.4643
# Epoch 6/15
# 56/56 [==============================] - 99s 2s/step - loss: 0.5868 - accuracy: 0.8054 - val_loss: 5.1082 - val_accuracy: 0.4786
# Epoch 7/15
# 56/56 [==============================] - 95s 2s/step - loss: 0.5616 - accuracy: 0.8286 - val_loss: 0.7476 - val_accuracy: 0.5857
# Epoch 8/15
# 56/56 [==============================] - 95s 2s/step - loss: 0.5493 - accuracy: 0.8393 - val_loss: 3.4723 - val_accuracy: 0.3143
# Epoch 9/15
# 56/56 [==============================] - 95s 2s/step - loss: 0.4366 - accuracy: 0.8518 - val_loss: 3.6381 - val_accuracy: 0.5429
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/15
# 56/56 [==============================] - 95s 2s/step - loss: 0.3915 - accuracy: 0.8571 - val_loss: 0.0588 - val_accuracy: 0.8857
# Epoch 11/15
# 56/56 [==============================] - 97s 2s/step - loss: 0.4321 - accuracy: 0.8643 - val_loss: 0.9554 - val_accuracy: 0.6500
# Epoch 12/15
# 56/56 [==============================] - 96s 2s/step - loss: 0.3395 - accuracy: 0.8821 - val_loss: 4.4008 - val_accuracy: 0.3214
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/15
# 56/56 [==============================] - 96s 2s/step - loss: 0.3096 - accuracy: 0.8875 - val_loss: 2.2901 - val_accuracy: 0.4643
# Epoch 14/15
# 56/56 [==============================] - 95s 2s/step - loss: 0.2988 - accuracy: 0.9054 - val_loss: 0.5331 - val_accuracy: 0.8143
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/15
# 56/56 [==============================] - 97s 2s/step - loss: 0.3091 - accuracy: 0.8821 - val_loss: 0.0246 - val_accuracy: 0.9143

# %%
model.save_weights("COVID-Model-{}-{}-{}-{}.h5".format(IMAGE_WIDTH, 3, batch_size, epochs))

# %% [markdown]
# # Graph Model Performance

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1, epochs + 1)
plt.plot(epochs, loss_train, 'g', label='Val loss')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir(path + 'test')

test_df = pd.DataFrame({
    'filename': test_filenames
})

nb_samples = test_df.shape[0]

# %%
test_df = test_df.sample(frac=1).reset_index(drop=True)
test_df
# Out:
#                       filename
# 0             NORMAL (630).png
# 1    Viral Pneumonia (359).png
# 2             NORMAL (376).png
# 3             NORMAL (638).png
# 4    Viral Pneumonia (650).png
# 5    Viral Pneumonia (451).png
# 6    Viral Pneumonia (611).png
# 7    Viral Pneumonia (487).png
# 8    Viral Pneumonia (408).png
# 9           COVID-19 (285).jpg
# 10            NORMAL (518).png
# 11            NORMAL (461).png
# 12   Viral Pneumonia (375).png
# 13            NORMAL (621).png
# 14            NORMAL (495).png
# 15   Viral Pneumonia (419).png
# 16          COVID-19 (273).jpg
# 17          COVID-19 (232).jpg
# 18            NORMAL (358).png
# 19   Viral Pneumonia (601).png
# 20   Viral Pneumonia (604).png
# 21   Viral Pneumonia (402).png
# 22   Viral Pneumonia (472).png
# 23            NORMAL (442).png
# 24   Viral Pneumonia (522).png
# 25   Viral Pneumonia (641).png
# 26            NORMAL (598).png
# 27   Viral Pneumonia (546).png
# 28   Viral Pneumonia (437).png
# 29          COVID-19 (222).jpg
# ..                         ...
# 659           NORMAL (491).png
# 660  Viral Pneumonia (643).png
# 661         COVID-19 (218).jpg
# 662           NORMAL (447).png
# 663         COVID-19 (242).jpg
# 664           NORMAL (390).png
# 665           NORMAL (443).png
# 666           NORMAL (419).png
# 667         COVID-19 (241).jpg
# 668  Viral Pneumonia (438).png
# 669  Viral Pneumonia (417).png
# 670           NORMAL (428).png
# 671  Viral Pneumonia (496).png
# 672           NORMAL (534).png
# 673  Viral Pneumonia (354).png
# 674         COVID-19 (215).jpg
# 675  Viral Pneumonia (559).png
# 676  Viral Pneumonia (400).png
# 677           NORMAL (362).png
# 678           NORMAL (426).png
# 679           NORMAL (388).png
# 680           NORMAL (549).png
# 681           NORMAL (507).png
# 682  Viral Pneumonia (404).png
# 683           NORMAL (578).png
# 684           NORMAL (511).png
# 685           NORMAL (555).png
# 686           NORMAL (588).png
# 687           NORMAL (551).png
# 688           NORMAL (483).png
#
# [689 rows x 1 columns]

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale = 1./255)
test_generator = test_gen.flow_from_dataframe(
    
    test_df, 
    path + '\\test', 
    x_col = 'filename',
    y_col = None,
    class_mode = None,
    target_size = IMAGE_SIZE,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 689 validated image filenames.

# %% [markdown]
# # Predict Diagnosis

# %%
predict = model.predict_generator(test_generator, steps = np.ceil(nb_samples/batch_size))

# %% [markdown]
# ## Pick the category that has the highest probability

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({'Normal': 0, 'COVID-19': 1, 'Viral Pneumonia': 2})

# %%
test_df['category'].value_counts().plot.bar()

# %% [markdown]
# # Predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()

plt.figure(figsize=(12, 24))

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    category = row['category']
    
    img = load_img(path + 'test\\' + filename, target_size=IMAGE_SIZE)
    
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + ' Pred: (' + "{}".format(category) + ')' )
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Calculate Model Accuracy

# %%
sample_test = test_df
correctPredictions = 0

correctNormalPred = 0
correctCovidPred = 0
correctPneuPred = 0

totalNormalPred = 0
totalCovidPred = 0
totalPneuPred = 0

for index, row in sample_test.iterrows():
    
    filename = row['filename']
    prediction = row['category']
    
    img = load_img(path + 'test\\' + filename, target_size=IMAGE_SIZE)
    
    if 'NORMAL' in filename:
        
        if prediction == 0:
            correctPredictions += 1
            correctNormalPred += 1
            
        totalNormalPred += 1
    
    if 'COVID-19' in filename:
        
        if prediction == 1: 
            correctPredictions += 1
            correctCovidPred += 1
            
        totalCovidPred += 1
    
    if 'Viral Pneumonia' in filename:
        
        if prediction == 2: 
            correctPredictions += 1
            correctPneuPred += 1
            
        totalPneuPred += 1

# %%
print('Model Accuracy:', "{:.2%}".format(correctPredictions / test_df.shape[0]))
print('Correct Predictions:', correctPredictions, 'Total Predictions:', test_df.shape[0])

print('\nNormal Predictions:', correctNormalPred, 'Accuracy', "{:.2%}".format(correctNormalPred /  totalNormalPred))
print('COVID-19 Predictions:', correctCovidPred, 'Accuracy', "{:.2%}".format(correctCovidPred /  totalCovidPred))
print('Viral Pneumonia Predictions:', correctPneuPred, 'Accuracy', "{:.2%}".format(correctPneuPred / totalPneuPred))
# Out:
# Model Accuracy: 91.29%
# Correct Predictions: 629 Total Predictions: 689
#
# Normal Predictions: 293 Accuracy 97.67%
# COVID-19 Predictions: 83 Accuracy 93.26%
# Viral Pneumonia Predictions: 253 Accuracy 84.33%

# %%
actual = []
pred = []

for row in test_df.iterrows():
    
    filename = row[1][0]
    
    if 'NORMAL' in filename: actual.append(0)
    if 'COVID-19' in filename: actual.append(1)
    if 'Viral Pneumonia' in filename: actual.append(2)
        
    pred.append(row[1][1])

# %%
print(classification_report(actual, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       300
#            1       0.87      0.93      0.90        89
#            2       0.97      0.84      0.90       300
#
#    micro avg       0.91      0.91      0.91       689
#    macro avg       0.91      0.92      0.91       689
# weighted avg       0.92      0.91      0.91       689

# %%
confusion_matrix(actual, pred)
# Out:
# array([[293,   4,   3],
#        [  0,  83,   6],
#        [ 39,   8, 253]], dtype=int64)
